# %% [markdown]
# # Tuples
# Tuple is a data structure which is, in many ways, similar to a list. The most important differences between the two are:
#
# Tuples are enclosed in parentheses (), while lists are enclosed in square brackets []
# Tuples are immutable, while the contents of a list may change
#
# The items stored in a tuple are accessed by index, just like the items stored in a list:
# ```Python
# point = (10, 20)
# print("x coordinate:", point[0])
# print("y coordinate:", point[1])
# ```
#
# Some key Points:
# -Tuples can be used as keys in dictionaries.
# -Tuples can be used to store multiple variables together

# %%
###A Piece of code that integrates the Use of tuples with most everything to create an expansive student databse:
def add_student(list, name):
    list[name]=""

def print_student(list, name):
    total=0
    it=0
    if name in list:
        if list[name]=="" or list[name]==[]:
            print(f"{name}:")
            print(" no completed courses")
        else:
            print(f"{name}:")
            print(f" {len(list[name])} completed courses:")
            for item in list[name]:
                print(f"  {item[0]} {item[1]}")
                total+=item[1]
                it+=1
            print(f" average grade {total/it}")
    else:
        print (f"{name}: no such person in the database")

def add_course(list, name, tuple):
    if list[name]=="":
        list[name]=[]
    else:
        for item in list[name]:
            if item[0]==tuple[0] and item[1]>=tuple[1]:
                return
            elif item[0]==tuple[0] and item[1]<tuple[1]:
                list[name].remove(item)
    if tuple[1]==0:
        return
    (list[name]).append(tuple)

def summary(list):
    maxi=0
    name=""
    total=0
    it=0
    print("students", len(list))
    for item in list:
        if len(list[item])>maxi:
            maxi=len(list[item])
            name=item
    print(f"most courses completed {maxi} {name}")
    maxi=0
    for nam in list:
     for item in list[nam]:
        total+=item[1]
        it+=1
     avg=total/it
     if avg>maxi:
         maxi=avg
         name=nam
    print(f"best average grade {maxi} {name}")




if __name__=="__main__":
 students = {}
 add_student(students, "Peter")
 add_course(students, "Peter", ("Introduction to Programming", 5))
 add_course(students, "Peter", ("Data Structures and Algorithms", 3))
 add_course(students, "Peter", ("Data Structures and Algorithms", 2))
 print_student(students, "Peter")
 summary(students)
 students = {}
 add_student(students, "Peter")
 add_course(students, "Peter", ("Software Development Methods", 0))
 print_student(students, "Peter")
# Out:
# Peter:
#  2 completed courses:
#   Introduction to Programming 5
#   Data Structures and Algorithms 3
#  average grade 4.0
# students 1
# most courses completed 2 Peter
# best average grade 4.0 Peter
# Peter:
#  no completed courses
